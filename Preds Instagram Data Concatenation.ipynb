# %%
import pandas as pd

# %%
posts1 = pd.read_csv("Instagram Raw Data/Preds Instagram Posts Sep 5 '23 - Oct 23 '23.csv")
posts2 = pd.read_csv("Instagram Raw Data/Preds Instagram Posts Sep 5 '22 - Sep 4 '23.csv")
posts_all = pd.concat([posts1, posts2], ignore_index=True)
posts_all.drop_duplicates("timestamp").reset_index(drop=True, inplace=True)              # Dropping duplicate posts because of the overlapping time frame
posts_all
# Out:
#                     timestamp hashtags/0     type  isSponsored ownerUsername  \
# 0    2023-10-22T01:14:51.000Z        NaN  Sidecar        False      predsnhl
# 1    2023-10-22T04:09:40.000Z        NaN    Video        False      predsnhl
# 2    2023-10-22T02:14:16.000Z        NaN  Sidecar        False      predsnhl
# 3    2023-10-21T19:01:04.000Z      Preds    Image        False      predsnhl
# 4    2023-10-22T00:48:04.000Z        NaN  Sidecar        False      predsnhl
# ..                        ...        ...      ...          ...           ...
# 949  2022-09-05T16:58:28.000Z        NaN  Sidecar        False      predsnhl
# 950  2022-09-06T13:25:18.000Z        NaN    Image        False      predsnhl
# 951  2022-09-08T16:06:53.000Z        NaN    Image        False      predsnhl
# 952  2022-09-13T00:35:43.000Z        NaN    Video        False      predsnhl
# 953  2022-09-09T19:59:29.000Z        NaN  Sidecar        False      predsnhl
#
# ...

# %%
posts_all.head(50)
# Out:
#                    timestamp  hashtags/0     type  isSponsored ownerUsername  \
# 0   2023-10-22T01:14:51.000Z         NaN  Sidecar        False      predsnhl
# 1   2023-10-22T04:09:40.000Z         NaN    Video        False      predsnhl
# 2   2023-10-22T02:14:16.000Z         NaN  Sidecar        False      predsnhl
# 3   2023-10-21T19:01:04.000Z       Preds    Image        False      predsnhl
# 4   2023-10-22T00:48:04.000Z         NaN  Sidecar        False      predsnhl
# 5   2023-10-21T14:19:39.000Z         NaN    Image        False      predsnhl
# 6   2023-10-22T03:28:30.000Z         NaN    Image        False      predsnhl
# 7   2023-10-22T02:31:38.000Z         NaN  Sidecar        False      predsnhl
# 8   2023-10-21T23:46:23.000Z         NaN    Image        False      predsnhl
# 9   2023-10-22T01:38:37.000Z         NaN    Image        False      predsnhl
# 10  2023-10-20T00:51:42.000Z         NaN    Video        False      predsnhl
# ...

# %%
len(posts_all)
# Out:
# 954

# %%
posts_all.isnull().sum()
# Out:
# timestamp          0
# hashtags/0       915
# type               0
# isSponsored        0
# ownerUsername      0
# productType      603
# alt              954
# caption            3
# locationId       307
# url                0
# locationName     307
# ownerId            0
# displayUrl         0
# likesCount         0
# commentsCount      0
# id                 0
# ownerFullName      0
# hashtags/1       948
# hashtags/2       953
# hashtags/3       953
# hashtags/4       953
# hashtags/5       953
# hashtags/6       953
# hashtags/7       953
# hashtags/8       953
# hashtags/9       953
# dtype: int64

# %%
posts_all.drop("alt", axis=1, inplace=True)

# %%
posts_all.to_csv("Instagram Concatenated Data/Preds Instagram Posts", index=False)

# %%
posts_all.loc[0,"url"]
# Out:
# 'https://www.instagram.com/p/CyrqnD_Onxz/'

# %%
comments1 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 1-100.csv")
comments2 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 101-200.csv")
comments3 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 201-300.csv")
comments4 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 301-400.csv")
comments5 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 401-500.csv")
comments6 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 501-600.csv")
comments7 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 601-700.csv")
comments8 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 701-800.csv")
comments9 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 801-900.csv")
comments10 = pd.read_csv("Instagram Raw Data/Preds Instagram Comments Posts 901-954.csv")

# %%
comments_all = pd.concat([comments1, comments2, comments3, comments4, comments5, comments6, comments7, comments8, comments9, comments10], ignore_index=True)
comments_all.drop_duplicates(["timestamp", "text"]).reset_index(drop=True, inplace=True) 
comments_all
# Out:
#                       id  likesCount      ownerUsername  \
# 0      18119094331319283           2         dagroot_22
# 1      17876330351973126           4        phats_sphem
# 2      18018161899855273          15         preds_debs
# 3      18306827734136835           0    cleanjuicegulch
# 4      17881418045905767           0          sdparks66
# ...                  ...         ...                ...
# 16625  17972971831749039           0  thestephaniehenry
# 16626  17939505191467850           1       hockeygirl35
# 16627  17918646752503215           0     igo_onwebsites
# 16628  18249982543188957           0         preds_debs
# 16629  18185239939210502           0  taratoccogoldberg
#
#                                         postUrl  \
# 0      https://www.instagram.com/p/Cyr-k8SMFeM/
# 1      https://www.instagram.com/p/Cyr-k8SMFeM/
# 2      https://www.instagram.com/p/Cyr-k8SMFeM/
# 3      https://www.instagram.com/p/Cyr-k8SMFeM/
# ...

# %%
len(comments_all)
# Out:
# 16630

# %%
comments_all.isnull().sum()
# Out:
# id                0
# likesCount        0
# ownerUsername     0
# postUrl           0
# text             38
# timestamp         0
# dtype: int64

# %%
comments_all.to_csv("Instagram Concatenated Data/Preds Instagram Comments", index=False)
