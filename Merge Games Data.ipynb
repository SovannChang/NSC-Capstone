# %%
import pandas as pd
import ast

# %%
def aspects_to_dict(aspect_string):
    aspects_dict = dict(ast.literal_eval(aspect_string))
    
    return aspects_dict

# %% [markdown]
# ## NSC DATA

# %%
nsc_data = pd.read_csv("ABSA_Reddit_Results/nsc_run_1_res.csv", index_col=0)
nsc_data.tail()
# Out:
#           id                                              Title  \
# 1151  v4o448                Season Ticket Holder Scarf Question
# 1152  ua9rgq  Bidding for our Hearts for Ukraine fundraiser ...
# 1153  tyl8nw                   Someone tell me it's gonna be ok
# 1154  s786ep        Nashville Soccer Club Waives Miguel Nazarit
# 1155  vifbqy                                             Vague?
#
#                                                 Content                Author  \
# 1151  For any of you that have the season ticket hol...          trillwilly69
# 1152                                                NaN        Bootleggers_SG
# 1153  I haven't received any kind of communications ...              R-Smelly
# 1154                                                NaN               JAShock
# 1155                                                NaN  Actual_Illustrator59
#
#                 Post Date                                    cleaned_results
# 1151  2022-06-04 12:43:51  [('stadium amenities', 0.13), ('pricing', -0.3...
# 1152  2022-04-23 16:57:25                          [('miscellaneous', 0.15)]
# 1153  2022-04-07 19:52:58                       [('stadium amenities', 0.5)]
# 1154  2022-01-18 21:18:33  [('coaching and management', -0.73), ('pricing...
# 1155  2022-06-22 20:59:16  [('team performance', -0.09), ('coaching and m...

# %%
new_cleaned_results = pd.DataFrame(nsc_data.loc[:, "cleaned_results"].apply(aspects_to_dict))

# %%
nsc_data.drop("cleaned_results", axis=1, inplace=True)
nsc_data["cleaned_results"] = new_cleaned_results

# Sort by Post Date
nsc_data_sorted = nsc_data.sort_values(by="Post Date").reset_index(drop=True)

# Remove timestamp from Post Date column
nsc_data_sorted["Post Date"] = pd.to_datetime(nsc_data_sorted["Post Date"]).dt.date
nsc_data_sorted.tail()
# Out:
#            id                                              Title  \
# 1109  17s5yif                 2023 end-of-season fan survey [OC]
# 1110  17x7oyy                                Homecoming Kit Sale
# 1111  17xk4ov  D.C. United hires Nashville SC’s Ally Mackay a...
# 1112  183py9a  Hany Mukhtar is making the case that he is mor...
# 1113  1840b9u                               ISO Matchday Posters
#
#                                                 Content             Author  \
# 1109                                                NaN  speedwaysoccerpod
# 1110  Adidas has a huge markdown on this in their Bl...  SportsSpectacular
# 1111                                                NaN             pasoud
# 1112                                                NaN   ottersaregreat10
# 1113  Hello! I am looking to buy matchday posters fr...      beanerwiener8
#
#        Post Date                                    cleaned_results
# 1109  2023-11-10  {'team performance': -0.61, 'stadium amenities...
# 1110  2023-11-17  {'pricing': 0.82, 'stadium amenities': 0.45, '...
# 1111  2023-11-17  {'coaching and management': 0.17, 'miscellaneo...
# 1112  2023-11-25  {'team performance': -0.89, 'stadium atmospher...
# 1113  2023-11-26                            {'miscellaneous': -0.6}

# %%
aspects = ["team performance", "coaching and management", "stadium atmosphere", "stadium amenities", "pricing", "media coverage", "miscellaneous"]

for aspect in aspects:
    nsc_data_sorted[aspect] = nsc_data_sorted["cleaned_results"].apply(lambda x: x.get(aspect) if x and aspect in x else None)
    
nsc_data_sorted.drop("cleaned_results", axis=1, inplace=True)
nsc_data_sorted.tail()
# Out:
#            id                                              Title  \
# 1109  17s5yif                 2023 end-of-season fan survey [OC]
# 1110  17x7oyy                                Homecoming Kit Sale
# 1111  17xk4ov  D.C. United hires Nashville SC’s Ally Mackay a...
# 1112  183py9a  Hany Mukhtar is making the case that he is mor...
# 1113  1840b9u                               ISO Matchday Posters
#
#                                                 Content             Author  \
# 1109                                                NaN  speedwaysoccerpod
# 1110  Adidas has a huge markdown on this in their Bl...  SportsSpectacular
# 1111                                                NaN             pasoud
# 1112                                                NaN   ottersaregreat10
# 1113  Hello! I am looking to buy matchday posters fr...      beanerwiener8
#
#        Post Date  team performance  coaching and management  \
# 1109  2023-11-10             -0.61                    -0.50
# 1110  2023-11-17               NaN                      NaN
# 1111  2023-11-17               NaN                     0.17
# 1112  2023-11-25             -0.89                      NaN
# 1113  2023-11-26               NaN                      NaN
#
#       stadium atmosphere  stadium amenities  pricing  media coverage  \
# 1109                0.00               0.00     0.00            0.56
# 1110                 NaN               0.45     0.82             NaN
# 1111                 NaN                NaN      NaN             NaN
# 1112                0.23                NaN      NaN             NaN
# 1113                 NaN                NaN      NaN             NaN
#
#       miscellaneous
# 1109           0.31
# 1110           0.77
# 1111           0.05
# 1112           0.00
# 1113          -0.60

# %%
nsc_games = pd.read_csv("Games Data Cleaned/NSC Games.csv", index_col=0)
nsc_games.rename(columns={"Date": "Game Date"}, inplace=True)
nsc_games["Game Date"] = pd.to_datetime(nsc_games["Game Date"]).dt.date
nsc_games.head()
# Out:
#     Game Date Comp           Round Venue Result  Score  Opponent   xG  xGA  \
# 0  2022-02-27  MLS  Regular Season  Away      W      1         0  1.0  0.5
# 1  2022-03-05  MLS  Regular Season  Away      D      1         1  1.7  1.9
# 2  2022-03-12  MLS  Regular Season  Away      L      0         2  0.2  1.7
# 3  2022-03-19  MLS  Regular Season  Away      L      1         2  2.3  0.9
# 4  2022-04-02  MLS  Regular Season  Away      W      1         0  0.9  1.7
#
#    Attendance  Percent
# 0       30013      0.0
# 1       18107      0.0
# 2       13448      0.0
# 3       20036      0.0
# 4       20371      0.0

# %%
nsc_merged = nsc_data_sorted.merge(nsc_games, how="left", left_on="Post Date", right_on="Game Date")
nsc_merged.tail()
# Out:
#            id                                              Title  \
# 1109  17s5yif                 2023 end-of-season fan survey [OC]
# 1110  17x7oyy                                Homecoming Kit Sale
# 1111  17xk4ov  D.C. United hires Nashville SC’s Ally Mackay a...
# 1112  183py9a  Hany Mukhtar is making the case that he is mor...
# 1113  1840b9u                               ISO Matchday Posters
#
#                                                 Content             Author  \
# 1109                                                NaN  speedwaysoccerpod
# 1110  Adidas has a huge markdown on this in their Bl...  SportsSpectacular
# 1111                                                NaN             pasoud
# 1112                                                NaN   ottersaregreat10
# 1113  Hello! I am looking to buy matchday posters fr...      beanerwiener8
#
#        Post Date  team performance  coaching and management  \
# 1109  2023-11-10             -0.61                    -0.50
# 1110  2023-11-17               NaN                      NaN
# 1111  2023-11-17               NaN                     0.17
# 1112  2023-11-25             -0.89                      NaN
# 1113  2023-11-26               NaN                      NaN
#
#       stadium atmosphere  stadium amenities  pricing  ...  Comp  Round Venue  \
# 1109                0.00               0.00     0.00  ...   NaN    NaN   NaN
# 1110                 NaN               0.45     0.82  ...   NaN    NaN   NaN
# 1111                 NaN                NaN      NaN  ...   NaN    NaN   NaN
# 1112                0.23                NaN      NaN  ...   NaN    NaN   NaN
# 1113                 NaN                NaN      NaN  ...   NaN    NaN   NaN
#
#      Result Score Opponent  xG  xGA  Attendance  Percent
# 1109    NaN   NaN      NaN NaN  NaN         NaN      NaN
# 1110    NaN   NaN      NaN NaN  NaN         NaN      NaN
# 1111    NaN   NaN      NaN NaN  NaN         NaN      NaN
# 1112    NaN   NaN      NaN NaN  NaN         NaN      NaN
# 1113    NaN   NaN      NaN NaN  NaN         NaN      NaN
#
# [5 rows x 23 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(nsc_merged.loc[32:35, :])
# Out:
#         id                                              Title  \
# 32  szyl0j  Aké Loba: is it just me, or is he noticeably a...
# 33  t2nb5w                                           ahem....
# 34  t321fu               Here it is: Your opening day lineup.
# 35  t3575e  [Post-Match thread] Seattle Sounders vs Nashvi...
#
#                                               Content        Author  \
# 32                                                NaN  deltasig1985
# 33  LETSSSSSSSSSSSSSSSSGGOOOOOOOOOOOOOOOOOOOOOOOOO...    wolfhickey
# 34                                                NaN  Moderator451
# 35  # [Major League Soccer - 2022/2023]\r\n#Seattl...   MatchCaster
#
#      Post Date  team performance  coaching and management  stadium atmosphere  \
# 32  2022-02-24             -0.05                     0.12                 NaN
# 33  2022-02-27               NaN                      NaN                0.82
# 34  2022-02-28              0.28                     0.29               -0.73
# 35  2022-02-28              0.65                      NaN                0.60
#
#     stadium amenities  pricing  media coverage  miscellaneous   Game Date  \
# 32                NaN      NaN           -0.50           -0.2         NaN
# 33                NaN      NaN             NaN            NaN  2022-02-27
# 34               0.85    -0.95            0.92            NaN         NaN
# 35                NaN      NaN             NaN           -0.3         NaN
#
#    Comp           Round Venue Result  Score  Opponent   xG  xGA  Attendance  \
# 32  NaN             NaN   NaN    NaN    NaN       NaN  NaN  NaN         NaN
# 33  MLS  Regular Season  Away      W    1.0       0.0  1.0  0.5     30013.0
# 34  NaN             NaN   NaN    NaN    NaN       NaN  NaN  NaN         NaN
# 35  NaN             NaN   NaN    NaN    NaN       NaN  NaN  NaN         NaN
#
#     Percent
# 32      NaN
# 33      0.0
# 34      NaN
# 35      NaN

# %% [markdown]
# Write to a file

# %%
nsc_merged.to_csv("Scored Data With Games/nsc_scored_with_games.csv", index=False)

# %% [markdown]
# ## PREDS DATA

# %%
preds_data = pd.read_csv("ABSA_Reddit_Results/preds_run_1_res.csv", index_col=0)
preds_data.tail()
# Out:
#           id                                              Title  \
# 964  11d3381  What the addition of Foote, probably means to us.
# 965   w4p1xv          Just an idea for a Matthew Tkachuck trade
# 966   t0v4ns  Can someone make this a shirt or hat or someth...
# 967   zjfega                        Smashville Stocking Stuffer
# 968   ujsxg8  On ticket master is the lower the letter in th...
#
#                                                Content            Author  \
# 964  McDonagh paired with Foote in TB a lot last ye...  MusicCityJayhawk
# 965                                                NaN            mk1700
# 966                                                NaN        aceofwades
# 967  Does anyone know how seating is decided? Ex. G...          jnkeegan
# 968                             Trying to buy a ticket         Bakio-bay
#
#                Post Date                                    cleaned_results
# 964  2023-02-27 04:51:11  [('coaching and management', 0.18), ('team per...
# 965  2022-07-21 19:14:00  [('team performance', -0.32), ('miscellaneous'...
# 966  2022-02-25 04:42:42                          [('miscellaneous', 0.28)]
# 967  2022-12-11 23:57:51  [('stadium amenities', -0.88), ('miscellaneous...
# 968  2022-05-06 17:42:19    [('pricing', 0.0), ('stadium amenities', 0.35)]

# %%
new_preds_cleaned_results = pd.DataFrame(preds_data.loc[:, "cleaned_results"].apply(aspects_to_dict))

# %%
preds_data.drop("cleaned_results", axis=1, inplace=True)
preds_data["cleaned_results"] = new_preds_cleaned_results

# Sort by Post Date
preds_data_sorted = preds_data.sort_values(by="Post Date").reset_index(drop=True)

# Remove timestamp from Post Date column
preds_data_sorted["Post Date"] = pd.to_datetime(preds_data_sorted["Post Date"]).dt.date
preds_data_sorted.tail()
# Out:
#           id                                         Title  \
# 933  183omt4     Who is the Preds biggest rival right now?
# 934  183v1a6  Has anybody ever bought this? I need to know
# 935  1844ldg                       Keep an eye on Svechkov
# 936  184btbo               Customized Reverse Retro Jersey
# 937  184ezp4                      Juuse always starts slow
#
#                                                Content             Author  \
# 933  Was thinking about it this week. Over our team...      ConBurgundy15
# 934  https://nashvillelockerroom.com/life-size-gnas...  ZeldaTheOuchMouse
# 935  Folks, keep an eye on Svechkov. Several of the...    TwinTowersJenga
# 936  Hey everyone!  Wife and I are going to the Jet...        Austinopril
# 937                                                NaN         Over-One-8
#
#       Post Date                                    cleaned_results
# 933  2023-11-25  {'team performance': 0.0, 'stadium amenities':...
# 934  2023-11-25        {'pricing': -0.1, 'stadium amenities': 0.0}
# 935  2023-11-26  {'team performance': 0.34, 'coaching and manag...
# 936  2023-11-26      {'stadium amenities': 0.25, 'pricing': -0.03}
# 937  2023-11-26  {'team performance': -0.36, 'coaching and mana...

# %%
aspects = ["team performance", "coaching and management", "stadium atmosphere", "stadium amenities", "pricing", "media coverage", "miscellaneous"]

for aspect in aspects:
    preds_data_sorted[aspect] = preds_data_sorted["cleaned_results"].apply(lambda x: x.get(aspect) if x and aspect in x else None)
    
preds_data_sorted.drop("cleaned_results", axis=1, inplace=True)
preds_data_sorted.tail()
# Out:
#           id                                         Title  \
# 933  183omt4     Who is the Preds biggest rival right now?
# 934  183v1a6  Has anybody ever bought this? I need to know
# 935  1844ldg                       Keep an eye on Svechkov
# 936  184btbo               Customized Reverse Retro Jersey
# 937  184ezp4                      Juuse always starts slow
#
#                                                Content             Author  \
# 933  Was thinking about it this week. Over our team...      ConBurgundy15
# 934  https://nashvillelockerroom.com/life-size-gnas...  ZeldaTheOuchMouse
# 935  Folks, keep an eye on Svechkov. Several of the...    TwinTowersJenga
# 936  Hey everyone!  Wife and I are going to the Jet...        Austinopril
# 937                                                NaN         Over-One-8
#
#       Post Date  team performance  coaching and management  \
# 933  2023-11-25              0.00                     0.02
# 934  2023-11-25               NaN                      NaN
# 935  2023-11-26              0.34                     0.18
# 936  2023-11-26               NaN                      NaN
# 937  2023-11-26             -0.36                    -0.24
#
#      stadium atmosphere  stadium amenities  pricing  media coverage  \
# 933               -0.05               0.08      NaN            0.04
# 934                 NaN               0.00    -0.10             NaN
# 935                0.06                NaN      NaN             NaN
# 936                 NaN               0.25    -0.03             NaN
# 937                 NaN                NaN      NaN             NaN
#
#      miscellaneous
# 933           0.16
# 934            NaN
# 935            NaN
# 936            NaN
# 937           0.17

# %%
preds_games = pd.read_csv("Games Data Cleaned/Preds Games.csv", index_col=0)
preds_games.rename(columns={"Date": "Game Date"}, inplace=True)
preds_games["Game Date"] = pd.to_datetime(preds_games["Game Date"]).dt.date
preds_games.head()
# Out:
#     Game Date Venue  Score  Opponent Result  Attendance   Percent
# 0  2022-01-01  Home      6         1      W       17504  0.982102
# 1  2022-01-04  Away      3         2      W       17804  0.000000
# 2  2022-01-06  Away      4         2      W       14359  0.000000
# 3  2022-01-08  Away      4         2      W       10317  0.000000
# 4  2022-01-11  Home      5         4      W       17159  0.962745

# %%
preds_merged = preds_data_sorted.merge(preds_games, how="left", left_on="Post Date", right_on="Game Date")
preds_merged.tail()
# Out:
#           id                                         Title  \
# 933  183omt4     Who is the Preds biggest rival right now?
# 934  183v1a6  Has anybody ever bought this? I need to know
# 935  1844ldg                       Keep an eye on Svechkov
# 936  184btbo               Customized Reverse Retro Jersey
# 937  184ezp4                      Juuse always starts slow
#
#                                                Content             Author  \
# 933  Was thinking about it this week. Over our team...      ConBurgundy15
# 934  https://nashvillelockerroom.com/life-size-gnas...  ZeldaTheOuchMouse
# 935  Folks, keep an eye on Svechkov. Several of the...    TwinTowersJenga
# 936  Hey everyone!  Wife and I are going to the Jet...        Austinopril
# 937                                                NaN         Over-One-8
#
#       Post Date  team performance  coaching and management  \
# 933  2023-11-25              0.00                     0.02
# 934  2023-11-25               NaN                      NaN
# 935  2023-11-26              0.34                     0.18
# 936  2023-11-26               NaN                      NaN
# 937  2023-11-26             -0.36                    -0.24
#
#      stadium atmosphere  stadium amenities  pricing  media coverage  \
# 933               -0.05               0.08      NaN            0.04
# 934                 NaN               0.00    -0.10             NaN
# 935                0.06                NaN      NaN             NaN
# 936                 NaN               0.25    -0.03             NaN
# 937                 NaN                NaN      NaN             NaN
#
#      miscellaneous Game Date Venue  Score  Opponent Result  Attendance  \
# 933           0.16       NaN   NaN    NaN       NaN    NaN         NaN
# 934            NaN       NaN   NaN    NaN       NaN    NaN         NaN
# 935            NaN       NaN   NaN    NaN       NaN    NaN         NaN
# 936            NaN       NaN   NaN    NaN       NaN    NaN         NaN
# 937           0.17       NaN   NaN    NaN       NaN    NaN         NaN
#
#      Percent
# 933      NaN
# 934      NaN
# 935      NaN
# 936      NaN
# 937      NaN

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(preds_merged.loc[338:343, :])
# Out:
#           id                                              Title  \
# 338  123vfz3               Jordan Gross (NASH) on waivers today
# 339  124bjdu                             Help for Covenant Kids
# 340  124sx95                      McCarron and Gravel up to NSH
# 341  1253nxk  [Scott McLaughlin] The Bruins will be showing ...
# 342  1256uiz                     Who are your favorite players?
# 343  12587h4                                    Caleb for Coach
#
#                                                Content              Author  \
# 338                                                NaN            Jmthrows
# 339  EDIT: I have heard from someone at the preds t...  KaleidoscopeOk1346
# 340                                                NaN     TwinTowersJenga
# 341                                                NaN   Kroger453PredsFan
# 342  Hey smashville, who are your favorite players?...           meinchman
# 343                                                NaN            Dalanard
#
#       Post Date  team performance  coaching and management  \
# 338  2023-03-27             -0.05                     0.12
# 339  2023-03-28               NaN                      NaN
# 340  2023-03-28              0.59                      NaN
# 341  2023-03-28               NaN                      NaN
# 342  2023-03-28              0.33                     0.17
# 343  2023-03-29               NaN                     0.16
#
#      stadium atmosphere  stadium amenities  pricing  media coverage  \
# 338                0.00                0.0      0.0            0.14
# 339                 NaN                NaN      NaN             NaN
# 340                 NaN                NaN      NaN             NaN
# 341                0.75                NaN      NaN             NaN
# 342                0.10                0.0      0.0            0.00
# 343                 NaN                NaN      NaN             NaN
#
#      miscellaneous   Game Date Venue  Score  Opponent Result  Attendance  \
# 338           0.04         NaN   NaN    NaN       NaN    NaN         NaN
# 339           0.43  2023-03-28  Away    2.0       1.0      W     17850.0
# 340           0.16  2023-03-28  Away    2.0       1.0      W     17850.0
# 341            NaN  2023-03-28  Away    2.0       1.0      W     17850.0
# 342           0.14  2023-03-28  Away    2.0       1.0      W     17850.0
# 343           0.55         NaN   NaN    NaN       NaN    NaN         NaN
#
#      Percent
# 338      NaN
# 339      0.0
# 340      0.0
# 341      0.0
# 342      0.0
# 343      NaN

# %% [markdown]
# Write to a file

# %%
preds_merged.to_csv("Scored Data With Games/preds_scored_with_games.csv", index=False)

# %% [markdown]
# ## TITANS DATA

# %%
titans_data = pd.read_csv("ABSA_Reddit_Results/titans_run_1_res.csv", index_col=0)
titans_data.tail()
# Out:
#            id                                              Title  \
# 1551   x0eryx                                     Titans Defense
# 1552   uu12r4            Derrick Henry buys new house in Dallas?
# 1553   s408wb      Who is better historically? Texans or Titans,
# 1554  13ir53i                           Do you want to be hated?
# 1555   tmluss  Ryan Tannehill. Having criticisms and doubts a...
#
#                                                 Content            Author  \
# 1551  This is NOT one of those “We get no respect 😠”...   rootbeercaveman
# 1552                                                NaN  BuffaloKiller937
# 1553  Debate time, which of those two are more succe...  PissedoffNflNerd
# 1554  So because we have Levis, who seems to be univ...   Emilio_Estevezz
# 1555                                                NaN     Deceptivejunk
#
#                 Post Date                                    cleaned_results
# 1551  2022-08-29 03:51:14  [('team performance', 0.14), ('media coverage'...
# 1552  2022-05-20 16:23:27                          [('miscellaneous', 0.16)]
# 1553  2022-01-14 19:19:48  [('team performance', -0.43), ('media coverage...
# 1554  2023-05-16 01:32:40  [('team performance', 0.27), ('media coverage'...
# 1555  2022-03-24 16:34:09  [('team performance', -0.07), ('coaching and m...

# %%
new_titans_cleaned_results = pd.DataFrame(titans_data.loc[:, "cleaned_results"].apply(aspects_to_dict))

# %%
titans_data.drop("cleaned_results", axis=1, inplace=True)
titans_data["cleaned_results"] = new_titans_cleaned_results

# Sort by Post Date
titans_data_sorted = titans_data.sort_values(by="Post Date").reset_index(drop=True)

# Remove timestamp from Post Date column
titans_data_sorted["Post Date"] = pd.to_datetime(titans_data_sorted["Post Date"]).dt.date
titans_data_sorted.tail()
# Out:
#            id                                              Title  \
# 1511  183wmqw  [Dianna Russini] “Sorry Buckeyes. You can cros...
# 1512  18494ao  Lions Fan Coming In Peace With a Random Questi...
# 1513  184dchi  Hellman’s added a last minute stop to their ga...
# 1514  184e5iq                 Gobble Hill says gobble gobble up!
# 1515  184exhx         Can Mods Please Change the Sub desktop Pic
#
#                                                 Content          Author  \
# 1511                                                NaN  derrick22henry
# 1512  Some of us were discussing this during the Mic...  MichiganMedium
# 1513  No kidding. They added this stop Friday. That’...  FilledUpTinCup
# 1514                                                NaN   Toastfrom2069
# 1515  It's Burks catching a pass vs the Bengals in a...  JustStrolling_
#
#        Post Date                                    cleaned_results
# 1511  2023-11-25  {'team performance': -0.1, 'media coverage': -...
# 1512  2023-11-26  {'team performance': 0.35, 'coaching and manag...
# 1513  2023-11-26                            {'miscellaneous': 0.21}
# 1514  2023-11-26                           {'miscellaneous': -0.28}
# 1515  2023-11-26                            {'miscellaneous': 0.03}

# %%
aspects = ["team performance", "coaching and management", "stadium atmosphere", "stadium amenities", "pricing", "media coverage", "miscellaneous"]

for aspect in aspects:
    titans_data_sorted[aspect] = titans_data_sorted["cleaned_results"].apply(lambda x: x.get(aspect) if x and aspect in x else None)
    
titans_data_sorted.drop("cleaned_results", axis=1, inplace=True)
titans_data_sorted.tail()
# Out:
#            id                                              Title  \
# 1511  183wmqw  [Dianna Russini] “Sorry Buckeyes. You can cros...
# 1512  18494ao  Lions Fan Coming In Peace With a Random Questi...
# 1513  184dchi  Hellman’s added a last minute stop to their ga...
# 1514  184e5iq                 Gobble Hill says gobble gobble up!
# 1515  184exhx         Can Mods Please Change the Sub desktop Pic
#
#                                                 Content          Author  \
# 1511                                                NaN  derrick22henry
# 1512  Some of us were discussing this during the Mic...  MichiganMedium
# 1513  No kidding. They added this stop Friday. That’...  FilledUpTinCup
# 1514                                                NaN   Toastfrom2069
# 1515  It's Burks catching a pass vs the Bengals in a...  JustStrolling_
#
#        Post Date  team performance  coaching and management  \
# 1511  2023-11-25             -0.10                    -0.03
# 1512  2023-11-26              0.35                    -0.15
# 1513  2023-11-26               NaN                      NaN
# 1514  2023-11-26               NaN                      NaN
# 1515  2023-11-26               NaN                      NaN
#
#       stadium atmosphere  stadium amenities  pricing  media coverage  \
# 1511                 NaN                NaN      NaN           -0.15
# 1512               -0.28               0.07      NaN            0.09
# 1513                 NaN                NaN      NaN             NaN
# 1514                 NaN                NaN      NaN             NaN
# 1515                 NaN                NaN      NaN             NaN
#
#       miscellaneous
# 1511            NaN
# 1512           0.00
# 1513           0.21
# 1514          -0.28
# 1515           0.03

# %%
titans_games = pd.read_csv("Games Data Cleaned/Titans Games.csv", index_col=0)
titans_games.rename(columns={"Date": "Game Date"}, inplace=True)
titans_games["Game Date"] = pd.to_datetime(titans_games["Game Date"]).dt.date
titans_games.head()
# Out:
#     Game Date Result Venue  Score  Opponent  Attendance   Percent
# 0  2022-01-02      W  Home     34         3       69091  0.994702
# 1  2022-01-09      W  Away     28        25       66722  0.000000
# 2  2022-01-22      L  Home     16        19       69242  0.996876
# 3  2022-09-11      L  Home     20        21       67805  0.976187
# 4  2022-09-19      L  Away      7        41       70683  0.000000

# %%
titans_merged = titans_data_sorted.merge(titans_games, how="left", left_on="Post Date", right_on="Game Date")
titans_merged.tail()
# Out:
#            id                                              Title  \
# 1511  183wmqw  [Dianna Russini] “Sorry Buckeyes. You can cros...
# 1512  18494ao  Lions Fan Coming In Peace With a Random Questi...
# 1513  184dchi  Hellman’s added a last minute stop to their ga...
# 1514  184e5iq                 Gobble Hill says gobble gobble up!
# 1515  184exhx         Can Mods Please Change the Sub desktop Pic
#
#                                                 Content          Author  \
# 1511                                                NaN  derrick22henry
# 1512  Some of us were discussing this during the Mic...  MichiganMedium
# 1513  No kidding. They added this stop Friday. That’...  FilledUpTinCup
# 1514                                                NaN   Toastfrom2069
# 1515  It's Burks catching a pass vs the Bengals in a...  JustStrolling_
#
#        Post Date  team performance  coaching and management  \
# 1511  2023-11-25             -0.10                    -0.03
# 1512  2023-11-26              0.35                    -0.15
# 1513  2023-11-26               NaN                      NaN
# 1514  2023-11-26               NaN                      NaN
# 1515  2023-11-26               NaN                      NaN
#
#       stadium atmosphere  stadium amenities  pricing  media coverage  \
# 1511                 NaN                NaN      NaN           -0.15
# 1512               -0.28               0.07      NaN            0.09
# 1513                 NaN                NaN      NaN             NaN
# 1514                 NaN                NaN      NaN             NaN
# 1515                 NaN                NaN      NaN             NaN
#
#       miscellaneous Game Date Result Venue  Score  Opponent  Attendance  \
# 1511            NaN       NaN    NaN   NaN    NaN       NaN         NaN
# 1512           0.00       NaN    NaN   NaN    NaN       NaN         NaN
# 1513           0.21       NaN    NaN   NaN    NaN       NaN         NaN
# 1514          -0.28       NaN    NaN   NaN    NaN       NaN         NaN
# 1515           0.03       NaN    NaN   NaN    NaN       NaN         NaN
#
#       Percent
# 1511      NaN
# 1512      NaN
# 1513      NaN
# 1514      NaN
# 1515      NaN

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(titans_merged.loc[216:221, :])
# Out:
#          id                                              Title  \
# 216  xmzlij               Everything That Could Go Wrong Has 😥
# 217  xnxsdh                                 That Second Half 😬
# 218  xnxwnl                            Doesn't feel like a win
# 219  xo14hf  Hot topic: Todd Downing called a very good gam...
# 220  xo4sv7  [Mike Herndon] #Titans rookie punter Ryan Ston...
# 221  xo572p                         Why can’t I just be happy?
#
#                                                Content                Author  \
# 216                                                NaN            IronMango1
# 217                                                NaN            IronMango1
# 218  I am finding it very, very hard to watch these...  Halo_LAN_Party_2nite
# 219  2nd half was more of bad luck at the end of dr...           air_volek07
# 220                                                NaN         HenryTheTitan
# 221  Glad for the win, but I’m still bitter about u...           baby_NayNay
#
#       Post Date  team performance  coaching and management  \
# 216  2022-09-24             -0.07                     0.19
# 217  2022-09-25              0.51                    -0.14
# 218  2022-09-25              0.27                      NaN
# 219  2022-09-25              0.02                    -0.10
# 220  2022-09-26              0.12                     0.00
# 221  2022-09-26             -0.05                    -0.17
#
#      stadium atmosphere  stadium amenities  pricing  media coverage  \
# 216                0.07                NaN     0.17             NaN
# 217                0.00                NaN      NaN             NaN
# 218               -0.07                NaN      NaN             NaN
# 219                 NaN                NaN      NaN           -0.09
# 220                 NaN                NaN      NaN             NaN
# 221                0.06                NaN      NaN             NaN
#
#      miscellaneous   Game Date Result Venue  Score  Opponent  Attendance  \
# 216          -0.07         NaN    NaN   NaN    NaN       NaN         NaN
# 217            NaN  2022-09-25      W  Home   24.0      22.0     68649.0
# 218            NaN  2022-09-25      W  Home   24.0      22.0     68649.0
# 219            NaN  2022-09-25      W  Home   24.0      22.0     68649.0
# 220            NaN         NaN    NaN   NaN    NaN       NaN         NaN
# 221            NaN         NaN    NaN   NaN    NaN       NaN         NaN
#
#       Percent
# 216       NaN
# 217  0.988338
# 218  0.988338
# 219  0.988338
# 220       NaN
# 221       NaN

# %% [markdown]
# Write to a file

# %%
titans_merged.to_csv("Scored Data With Games/titans_scored_with_games.csv", index=False)
